# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-Week10/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py

# FUNCTION DEFINITIONS

def add_players(roster):
    # Use a while loop to repeatedly ask for player names
    # If the user types "quit", stop the loop
    # Otherwise add the player name to the roster list using append()
    pass


def is_on_roster(roster, player_name):
    # Loop through the roster list
    # If the name matches the player being searched
    # return True
    # If the loop finishes without finding the name
    # return False
    pass


# PROGRAM LOGIC

# create empty list called roster

# call add_players function to fill the list

# ask user for a player name to search

# call is_on_roster function

# print result depending on True or False
